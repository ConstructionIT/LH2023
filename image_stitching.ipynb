# %%
from PIL import Image

# %%
img = Image.open("/home/enfycius/Desktop/total.png")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)
plt.show()

# %%
print(img.size)
# Out:
# (2479, 1860)

# %%
cropped_img = img.crop((0, 0, 500, img.size[1]))

# %%
plt.imshow(cropped_img)
plt.show()

# %%
section = 4

# %%
img.size[0]
# Out:
# 2479

# %%
img.size[0] / section
# Out:
# 619.75

# %%
# !pip3 install imutils
# Out:
# ...
# ^C
# ERROR: Operation cancelled by user

# %%
from imutils import paths
import numpy as np
import imutils
import cv2

# %%
imagePaths = sorted(list(paths.list_images("/home/enfycius/Desktop/ImgSets/")))

# %%
images = []

# %%
for imagePath in imagePaths:
    image = cv2.imread(imagePath)
    images.append(image)

# %%
len(images)
# Out:
# 5

# %%
stitcher = cv2.createStitcher() if imutils.is_cv3() else cv2.Stitcher_create()

# %%
(status, stitched) = stitcher.stitch(images)

# %%
plt.imshow(stitched)
plt.show()

# %%
# !pip3 install stitching
# Out:
# Error processing line 1 of /home/enfycius/anaconda3/lib/python3.10/site-packages/matplotlib-3.7.1-py3.10-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/home/enfycius/anaconda3/lib/python3.10/site.py", line 186, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 568, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 25.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.1/42.1 MB 28.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 45.7 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.0
#     Uninstalling numpy-1.25.0:
#       Successfully uninstalled numpy-1.25.0
# ...

# %%
# !pip3 install imutils
# Out:
# Error processing line 1 of /home/enfycius/anaconda3/lib/python3.10/site-packages/matplotlib-3.7.1-py3.10-nspkg.pth:
#
#   Traceback (most recent call last):
#     File "/home/enfycius/anaconda3/lib/python3.10/site.py", line 186, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#     File "<frozen importlib._bootstrap>", line 568, in module_from_spec
#   AttributeError: 'NoneType' object has no attribute 'loader'
#
# Remainder of file ignored
# ...

# %%
from imutils import paths
import numpy as np
import imutils
import cv2

# %%
imagePaths = sorted(list(paths.list_images("/home/enfycius/Desktop/ImgSets2/")))

# %%
imagePaths
# Out:
# ['/home/enfycius/Desktop/ImgSets2/1.png',
#  '/home/enfycius/Desktop/ImgSets2/2.png',
#  '/home/enfycius/Desktop/ImgSets2/3.png',
#  '/home/enfycius/Desktop/ImgSets2/4.png',
#  '/home/enfycius/Desktop/ImgSets2/5.png',
#  '/home/enfycius/Desktop/ImgSets2/6.png']

# %%
import stitching

stitcher = stitching.Stitcher()
panorama = stitcher.stitch(imagePaths)

# %%
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(2, 3)

for i in range(2):
    for j in range(3):
        axs[i, j].imshow(cv2.cvtColor(cv2.imread(imagePaths[((i + 1) + (i % 2)) * i + j]), cv2.COLOR_BGR2RGB))
        
plt.show()

# %%
plt.imshow(cv2.cvtColor(panorama, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
